# %%
# %load_ext ipycalcpad

import numpy as np
import pandas as pd
from pint import UnitRegistry, Quantity
from rich import print
u = UnitRegistry()

from ipycalcpad import Configuration

# %%
# %%calcpad
# ## Seismic Design Criteria
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# CalcPad(
#     lines=[
#         Line(
#             expressions=None,
#             arguments=Namespace(substitute=False, no_execute=False, debug=False),
#             comment='# Seismic Design Criteria'
#         )
#     ],
#     arguments=Namespace(substitute=False, no_execute=False, debug=False)
# )

# %%
# %%calcpad
# ### Site Criteria
# Lat = 47.5655; Lon = -122.6260 # site location:
# S_xs_1N = 1.29; S_xs_2N = 1.93 # short period spectral acceleration:
# S_x1_1N = 0.81; S_x1_2N = 1.21 # 1 second period spectral acceleration:
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# CalcPad(
#     lines=[
#         Line(
#             expressions=None,
#             arguments=Namespace(substitute=False, no_execute=False, debug=False),
#             comment='## Site Criteria'
#         ),
#         Line(
#             expressions=[
#                 Assign(target=Variable(obj=None, name='Lat'), expression=Literal(obj=47.5655)),
#                 Assign(target=Variable(obj=None, name='Lon'), expression=Literal(obj=-122.626))
#             ],
#             arguments=Namespace(substitute=False, no_execute=False, debug=False),
#             comment='site location:'
#         ),
#         Line(
#             expressions=[
#                 Assign(target=Variable(obj=None, name='S_xs_1N'), expression=Literal(obj=1.29)),
#                 Assign(target=Variable(obj=None, name='S_xs_2N'), expression=Literal(obj=1.93))
# ...

# %%
masstable = pd.DataFrame(
    index = ('Main', 'Mezz', 'Roof'),
    columns = ('W_x', 'x'),
    data = ((285.3*u.kip,  9.5*u.ft),
            (220.4*u.kip, 18.5*u.ft),
            (321.9*u.kip, 27.5*u.ft)),
)

masstable['Wx'] = masstable['W_x'] * masstable['x']
sum_Wx = masstable['Wx'].sum()

masstable['c_x'] = masstable['Wx'] / sum_Wx.m

# %%
# %%calcpad
# masstable ### Story Masses
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# CalcPad(
#     lines=[
#         LongLine(
#             expressions=[
#                 Variable(
#                     obj=            W_x          x                  Wx                             c_x
# Main  285.3 kip   9.5 foot  2710.35 foot * kip  0.17329603580562658 foot * kip
# Mezz  220.4 kip  18.5 foot   4077.4 foot * kip  0.26070332480818414 foot * kip
# Roof  321.9 kip  27.5 foot  8852.25 foot * kip   0.5660006393861893 foot * kip,
#                     name='masstable'
#                 )
#             ],
#             arguments=Namespace(substitute=False, no_execute=False, debug=False),
#             comment='## Story Masses'
#         )
#     ],
#     arguments=Namespace(substitute=False, no_execute=False, debug=False)
# )
