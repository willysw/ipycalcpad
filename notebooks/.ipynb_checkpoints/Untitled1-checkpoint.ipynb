# %%
# %load notebooks/test.py
# %cd ..

from rich import print
from rich.pretty import install
install()
from pint import UnitRegistry
u = UnitRegistry()

from ipycalcpad import CalcPad, Magic

get_ipython().register_magics(Magic)
# Out:
# /Users/willysw/Programming/Calcpad

# %%
pad = Magic().calcpad(
    line = '--debug --substitute',
    cell = "x = 3*u.kip\ny_0 = 12\nz = x*2*u.ft"
)
pad
# Out:
# Namespace(substitute=True, no_execute=False, debug=True)
# CalcPad(
# │   lines=[
# │   │   Line(
# │   │   │   expressions=[
# │   │   │   │   Assign(
# │   │   │   │   │   target=Variable(
# │   │   │   │   │   │   obj=None,
# │   │   │   │   │   │   name='x'
# │   │   │   │   │   ),
# │   │   │   │   │   expression=PintQuantity(
# │   │   │   │   │   │   obj=<Quantity(3, 'kip')>
# │   │   │   │   │   )
# │   │   │   │   )
# │   │   │   ],
# │   │   │   arguments=Namespace(substitute=True, no_execute=False, debug=True),
# │   │   │   comment=''
# │   │   ),
# │   │   Line(
# │   │   │   expressions=[
# │   │   │   │   Assign(
# │   │   │   │   │   target=Variable(
# │   │   │   │   │   │   obj=None,
# │   │   │   │   │   │   name='y_0'
# │   │   │   │   │   ),
# │   │   │   │   │   expression=Literal(
# │   │   │   │   │   │   obj=12
# │   │   │   │   │   )
# │   │   │   │   )
# │   │   │   ],
# │   │   │   arguments=Namespace(substitute=True, no_execute=False, debug=True),
# ...

# %%
# %%calcpad -s
# x = 3*u.kip
# y_0 = 12
# z = 1*u.ft
# 1*u.ft
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# CalcPad(
#     lines=[
#         Line(
#             expressions=[
#                 Assign(
#                     target=Variable(obj=None, name='x'),
#                     expression=PintQuantity(obj=<Quantity(3, 'kip')>)
#                 )
#             ],
#             arguments=Namespace(substitute=True, no_execute=False, debug=False),
#             comment=''
#         ),
#         Line(
#             expressions=[Assign(target=Variable(obj=None, name='y_0'), expression=Literal(obj=12))],
#             arguments=Namespace(substitute=True, no_execute=False, debug=False),
#             comment=''
#         ),
#         Line(
#             expressions=[
#                 Assign(
#                     target=Variable(obj=None, name='z'),
#                     expression=PintQuantity(obj=<Quantity(12.0, 'inch')>)
#                 )
# ...
