# %%
# %load_ext ipycalcpad

# %%
from math import *
import math
import ast
import numpy as np
from transform import UnitRegistry
u = UnitRegistry()

# %%
x = np.asarray([1,2,3], dtype=float)
a_s = 2*u.sq_in
f_y = 60*u.ksi
f_c = 3*u.ksi
b = 40*u.mm

# %%
# %%calcpad -t
# # R_n = (a_s*f_y)/(0.8*b*f_c)
# b*12*u.mm*u.s
# Out:
# ```markdown
# {'substitute': False, 'help': False, 'test': True}
# ```
# ```python
# TransformedLine(assign='', expression='', substituted='', comment='R_n = (a_s*f_y)/(0.8*b*f_c)')
# R_n = (a_s*f_y)/(0.8*b*f_c)
# ```
# R_n = (a_s*f_y)/(0.8*b*f_c)
# ```python
# TransformedLine(assign='', expression='{b}\\,{\\texttt{Quantity}({12})}', substituted='{\\left({40\\ \\mathrm{mm}}\\right)}\\,{\\texttt{Quantity}(\\left({12}\\right))}', comment='')
# Expr(
#   value=BinOp(
#     left=Name(id='b', ctx=Load()),
#     op=Mult(),
#     right=Call(
#       func=Name(id='Quantity', ctx=Load()),
#       args=[
#         Constant(value=12)],
#       keywords=[
#         keyword(
#           arg='units',
#           value=Constant(value='millimeter * second'))])))
# ```
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ...
